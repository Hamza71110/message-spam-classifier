# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\dellu\AppData\Roaming\Python\Python313\site-packages (3.9.4)
# Requirement already satisfied: click in C:\Users\dellu\AppData\Roaming\Python\Python313\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in C:\Users\dellu\AppData\Roaming\Python\Python313\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\dellu\AppData\Roaming\Python\Python313\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in C:\Users\dellu\AppData\Roaming\Python\Python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in C:\Users\dellu\AppData\Roaming\Python\Python313\site-packages (from click->nltk) (0.4.6)

# %%
# Essential Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import nltk

# %%
df = pd.read_csv('spam.csv', encoding='latin1')

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# ### **Data Cleaning**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'], inplace=True)
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={'v1':'target','v2':'text'}, inplace=True)
df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df.drop_duplicates(keep='first', inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (5169, 2)

# %% [markdown]
# ### **EDA**

# %%
df['target'].value_counts()
# Out:
# target
# ham     4516
# spam     653
# Name: count, dtype: int64

# %%
plt.pie(df['target'].value_counts(), labels=['not-spam','spam'], autopct='%0.2f')
plt.show()

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\dellu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
df['num_of_all_characters'] = df['text'].apply(lambda x: len(x))# for all characters including special characters also
df['num_of_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
df['num_of_sentences'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))
df.head()
# Out:
#   target                                               text  \
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...
#
#    num_of_all_characters  num_of_words  num_of_sentences
# 0                    111            24                 2
# 1                     29             8                 2
# 2                    155            37                 2
# 3                     49            13                 1
# 4                     61            15                 1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['target'] = le.fit_transform(df['target'])
df.head()
# Out:
#    target                                               text  \
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...
#
#    num_of_all_characters  num_of_words  num_of_sentences
# 0                    111            24                 2
# 1                     29             8                 2
# 2                    155            37                 2
# 3                     49            13                 1
# 4                     61            15                 1

# %%
df[['num_of_all_characters','num_of_words','num_of_sentences']].describe()
# Out:
#        num_of_all_characters  num_of_words  num_of_sentences
# count            5169.000000   5169.000000       5169.000000
# mean               78.977945     18.455794          1.965564
# std                58.236293     13.324758          1.448541
# min                 2.000000      1.000000          1.000000
# 25%                36.000000      9.000000          1.000000
# 50%                60.000000     15.000000          1.000000
# 75%               117.000000     26.000000          2.000000
# max               910.000000    220.000000         38.000000

# %%
df[df['target']==0][['num_of_all_characters', 'num_of_words', 'num_of_sentences']].describe()
# Out:
#        num_of_all_characters  num_of_words  num_of_sentences
# count            4516.000000   4516.000000       4516.000000
# mean               70.459256     17.123782          1.820195
# std                56.358207     13.493970          1.383657
# min                 2.000000      1.000000          1.000000
# 25%                34.000000      8.000000          1.000000
# 50%                52.000000     13.000000          1.000000
# 75%                90.000000     22.000000          2.000000
# max               910.000000    220.000000         38.000000

# %%
df[df['target']==1][['num_of_all_characters', 'num_of_words', 'num_of_sentences']].describe()
# Out:
#        num_of_all_characters  num_of_words  num_of_sentences
# count             653.000000    653.000000        653.000000
# mean              137.891271     27.667688          2.970904
# std                30.137753      7.008418          1.488425
# min                13.000000      2.000000          1.000000
# 25%               132.000000     25.000000          2.000000
# 50%               149.000000     29.000000          3.000000
# 75%               157.000000     32.000000          4.000000
# max               224.000000     46.000000          9.000000

# %%
sns.histplot(df[df['target']==0]['num_of_all_characters'])
sns.histplot(df[df['target']==1]['num_of_all_characters'],color='red')
# Out:
# <Axes: xlabel='num_of_all_characters', ylabel='Count'>

# %%
sns.histplot(df[df['target']==0]['num_of_words'])
sns.histplot(df[df['target']==1]['num_of_words'],color='red')
# Out:
# <Axes: xlabel='num_of_words', ylabel='Count'>

# %%
sns.histplot(df[df['target']==0]['num_of_sentences'])
sns.histplot(df[df['target']==1]['num_of_sentences'],color='red')
# Out:
# <Axes: xlabel='num_of_sentences', ylabel='Count'>

# %%
sns.pairplot(df, hue='target')
